# %%
# !pip install faiss-cpu sentence-transformers

# %%
import pandas as pd
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
# Out:
# WARNING:tensorflow:From C:\Users\91873\AppData\Roaming\Python\Python310\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#Load enriched dataset
df = pd.read_csv("arxiv_enriched.csv")

# %%
if "combined_text" not in df.columns:
    df["combined_text"] = df["title"].astype(str) + " " + df["abstract"].astype(str)

# %%
# load model
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
#Loop through all topics and build index for each
for topic in sorted(df["topic"].unique()):
    print(f"🔄 Processing Topic {topic}...")
    
    # Filter by topic
    df_filtered = df[df["topic"] == topic].reset_index(drop=True)

    # Encode using SentenceTransformer
    embeddings = model.encode(df_filtered["combined_text"].tolist(), show_progress_bar=True)

    # Build FAISS index
    dimension = embeddings.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(np.array(embeddings).astype("float32"))
# Out:
# 🔄 Processing Topic 0...
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# 🔄 Processing Topic 1...
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]
# 🔄 Processing Topic 2...
# Batches:   0%|          | 0/43 [00:00<?, ?it/s]
# 🔄 Processing Topic 3...
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# 🔄 Processing Topic 4...
# Batches:   0%|          | 0/41 [00:00<?, ?it/s]
# 🔄 Processing Topic 5...
# Batches:   0%|          | 0/45 [00:00<?, ?it/s]
# 🔄 Processing Topic 6...
# Batches:   0%|          | 0/46 [00:00<?, ?it/s]
# 🔄 Processing Topic 7...
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# 🔄 Processing Topic 8...
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# 🔄 Processing Topic 9...
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# Save filtered dataset and FAISS index
df_filtered.to_csv(f"topic_{topic}_filtered.csv", index=False)
faiss.write_index(index, f"topic_{topic}_faiss.index")
print(f"✅ Saved: topic_{topic}_filtered.csv + topic_{topic}_faiss.index")
# Out:
# ✅ Saved: topic_9_filtered.csv + topic_9_faiss.index
